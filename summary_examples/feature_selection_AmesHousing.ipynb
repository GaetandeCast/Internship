# %% [markdown]
# # Feature selection with impurity and permutation importance on the Ames Housing dataset.
# In this notebook, we will compare UFI, MDI and Permutation importance on their ability to perform feature selection on the high-dimensional Ames Housing dataset, and their associated computational cost.

# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import warnings

from sklearn.compose import make_column_transformer
from sklearn.datasets import fetch_openml
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.inspection import permutation_importance
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# # Data fetching

# %%
ames_housing = fetch_openml(data_id=42165, as_frame=True, return_X_y=False)
y = ames_housing["target"].astype(float)
ames_housing = ames_housing["data"].drop(columns="Id")
ames_housing.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0       2    2008        WD         Normal
# 1         NaN       0       5    2007        WD         Normal
# 2         NaN       0       9    2008        WD         Normal
# 3         NaN       0       2    2006        WD        Abnorml
# 4         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %% [markdown]
# # Data preprocessing

# %%
numerical_features = ames_housing.select_dtypes("number").columns
categorical_features = ames_housing.columns.difference(numerical_features)

categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="most_frequent")),
    ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

preprocessor = make_column_transformer(
    (categorical_pipeline, categorical_features),
    (SimpleImputer(strategy="mean"), numerical_features),
    remainder='passthrough'
)

ames_housing_transformed = preprocessor.fit_transform(ames_housing)

feature_names = (
    categorical_features.tolist() + 
    numerical_features.tolist()
)

ames_housing_preprocessed = pd.DataFrame(
    ames_housing_transformed,
    columns=feature_names,
    index=ames_housing.index
)

# %% [markdown]
# # Add random features of varying cardinality

# %%
random_cat_sizes = [2, 5, 10, 20, 50, 100]
random_features = dict()
n_sample = len(y)
rng = np.random.RandomState(42)

X = ames_housing_preprocessed.copy()
for cat_size in random_cat_sizes:
    X[f"random_cat_{cat_size}"] = rng.randint(0, cat_size, size=n_sample)
X["random_num"] = rng.normal(size=n_sample)

X.head()
# Out:
#    Alley  BldgType  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  \
# 0    0.0       0.0       3.0           3.0           2.0           5.0
# 1    0.0       0.0       3.0           1.0           0.0           5.0
# 2    0.0       0.0       3.0           2.0           2.0           5.0
# 3    0.0       0.0       1.0           3.0           0.0           5.0
# 4    0.0       0.0       3.0           0.0           2.0           5.0
#
#    BsmtQual  CentralAir  Condition1  Condition2  ...  MiscVal  MoSold  YrSold  \
# 0       2.0         1.0         2.0         2.0  ...      0.0     2.0  2008.0
# 1       2.0         1.0         1.0         2.0  ...      0.0     5.0  2007.0
# 2       2.0         1.0         2.0         2.0  ...      0.0     9.0  2008.0
# 3       3.0         1.0         2.0         2.0  ...      0.0     2.0  2006.0
# 4       2.0         1.0         2.0         2.0  ...      0.0    12.0  2008.0
#
#    random_cat_2  random_cat_5  random_cat_10  random_cat_20  random_cat_50  \
# 0             0             4              7             19             36
# 1             1             4              0             17             45
# 2             0             4              4              9             23
# 3             0             2              2              8             15
# 4             0             2              0              7             12
#
#    random_cat_100  random_num
# 0              68   -1.583187
# 1              53    0.114476
# 2              53    1.573412
# 3              27    0.558137
# 4              55   -0.105790
#
# [5 rows x 86 columns]

# %% [markdown]
# # Train and optimize a `RandomForestRegressor`.

# %%
# Define parameter grid for min_samples_leaf
param_grid = {"min_samples_leaf": [1, 5, 20, 100], "max_features":["log2", "sqrt", 1.0], "n_estimators": [10, 50, 100, 200, 400]}

# Initialize Random Forest
rf = RandomForestRegressor(random_state=rng, n_jobs=-1)
rf.fit(X, y)

# Set up GridSearchCV with cross-validation
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring="neg_mean_squared_error",
    return_train_score=True,
    n_jobs=-1,
    verbose=1,
)

# Fit the grid search
grid_search.fit(X, y)

# Get the best parameter and estimator
best_params = grid_search.best_params_
best_score_gs = grid_search.best_score_

print(f"Best params: {best_params}")
print(f"Best neg mse score: {best_score_gs:.3e}")

common_params = best_params
common_params["random_state"] = rng
common_params["n_jobs"] = -1
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# Best params: {'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 400}
# Best neg mse score: -9.035e+08

# %% [markdown]
# # Feature selection procedure

# %%
def feature_selection(method, common_params, X, y, verbose=False):
    start_time = time.time()
    warnings.filterwarnings(
        "ignore", message=r"The number of unique classes is greater than 50% .*"
    )

    if method == "permutation":
        # Test data is required for reliable permutation importance
        X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=int(0.2 * X.shape[0]), random_state=rng
        )
        common_params["oob_score"] = False

    elif method == "UFI":
        X_train, y_train = X, y
        # With oob_score=True, rf will compute UFI during fit
        common_params["oob_score"] = True

    # Define a rf regressor
    rf = RandomForestRegressor(**common_params)

    # Compute neg mse score for the model trained on the dataset with all the features
    cv_score = cross_val_score(
        rf, X_train, y_train, scoring="neg_mean_squared_error", cv=5, n_jobs=-1
    )
    new_score = cv_score.mean()
    prev_score = new_score
    best_score = new_score
    tol = cv_score.std()
    init_score = new_score

    # We keep removing features until the best cross validated score is degraded by at least one std
    while new_score > best_score - tol:
        prev_score = new_score

        # Store the best score and associated features
        if new_score > best_score:
            best_score = new_score
            best_columns = X_train.columns.to_list()
            tol = cv_score.std()
            
        # Re-fit the model
        rf.fit(X_train, y_train)

        # Compute feature importance
        if method == "permutation":
            importance = permutation_importance(
                rf,
                X_test,
                y_test,
                scoring="neg_mean_squared_error",
                n_repeats=5,
                n_jobs=-1,
                random_state=rng,
            ).importances_mean
        elif method == "UFI":
            importance = rf.unbiased_feature_importances_

        # Find the feature with the smallest importance
        smallest_column = X_train.columns.to_list()[np.argmin(importance)]

        # Remove the feature from the dataset
        X_train = X_train.drop(columns=smallest_column)
        if method == "permutation":
            X_test = X_test.drop(columns=smallest_column)

        # Compute a 5-fold cross-validated score on the reduced dataset
        cv_score = cross_val_score(
            rf, X_train, y_train, scoring="neg_mean_squared_error", cv=5, n_jobs=-1
        )
        new_score = cv_score.mean()
        if verbose:
            print(
                f"Dropped column: {smallest_column:15} Previous score: {prev_score:.2e}, New score: {new_score:.2e}"
            )
    run_time = time.time() - start_time
    return dict(
        run_time=run_time,
        init_score=init_score,
        best_score=best_score,
        best_columns=best_columns,
        final_score=prev_score,
        final_columns=X_train.columns.to_list()+[smallest_column],
    )

# %% [markdown]
# # UFI for feature selection
# We will use the importance given by UFI under `feature_importances_` to perform feature selection.

# %%
res_UFI = feature_selection("UFI", common_params, X, y, verbose=True)
print(
    f"UFI results:\n"
    f"Removed {len(X.columns) - len(res_UFI["final_columns"])} features in {res_UFI["run_time"]:6.1f} seconds. \n"
    f"Initial score: {res_UFI["init_score"]:.2e}, best score: {res_UFI["best_score"]:.2e}, final score: {res_UFI["final_score"]:.2e} \n"
    f"Remaining columns: {res_UFI["final_columns"]}"
)
# Out:
# Dropped column: random_cat_20   Previous score: -9.03e+08, New score: -9.13e+08
# Dropped column: random_cat_50   Previous score: -9.13e+08, New score: -8.81e+08
# Dropped column: random_cat_2    Previous score: -8.81e+08, New score: -8.97e+08
# Dropped column: random_num      Previous score: -8.97e+08, New score: -8.81e+08
# Dropped column: random_cat_100  Previous score: -8.81e+08, New score: -8.79e+08
# Dropped column: PoolArea        Previous score: -8.79e+08, New score: -8.86e+08
# Dropped column: random_cat_10   Previous score: -8.86e+08, New score: -8.86e+08
# Dropped column: LotConfig       Previous score: -8.86e+08, New score: -8.61e+08
# Dropped column: YrSold          Previous score: -8.61e+08, New score: -8.71e+08
# Dropped column: MoSold          Previous score: -8.71e+08, New score: -8.61e+08
# Dropped column: Fence           Previous score: -8.61e+08, New score: -8.63e+08
# Dropped column: PoolQC          Previous score: -8.63e+08, New score: -8.55e+08
# Dropped column: GarageQual      Previous score: -8.55e+08, New score: -8.35e+08
# Dropped column: random_cat_5    Previous score: -8.35e+08, New score: -8.45e+08
# Dropped column: BsmtHalfBath    Previous score: -8.45e+08, New score: -8.35e+08
# Dropped column: EnclosedPorch   Previous score: -8.35e+08, New score: -8.34e+08
# Dropped column: Condition2      Previous score: -8.34e+08, New score: -8.48e+08
# Dropped column: 3SsnPorch       Previous score: -8.48e+08, New score: -8.40e+08
# Dropped column: MiscVal         Previous score: -8.40e+08, New score: -8.23e+08
# Dropped column: LowQualFinSF    Previous score: -8.23e+08, New score: -8.29e+08
# Dropped column: BsmtFinType2    Previous score: -8.29e+08, New score: -8.48e+08
# Dropped column: MiscFeature     Previous score: -8.48e+08, New score: -8.39e+08
# Dropped column: Utilities       Previous score: -8.39e+08, New score: -8.41e+08
# Dropped column: Heating         Previous score: -8.41e+08, New score: -8.31e+08
# Dropped column: BsmtCond        Previous score: -8.31e+08, New score: -8.29e+08
# Dropped column: Street          Previous score: -8.29e+08, New score: -8.28e+08
# Dropped column: GarageCond      Previous score: -8.28e+08, New score: -8.45e+08
# Dropped column: Alley           Previous score: -8.45e+08, New score: -8.39e+08
# Dropped column: BsmtFinSF2      Previous score: -8.39e+08, New score: -8.38e+08
# Dropped column: ExterCond       Previous score: -8.38e+08, New score: -8.21e+08
# Dropped column: RoofMatl        Previous score: -8.21e+08, New score: -8.26e+08
# Dropped column: Condition1      Previous score: -8.26e+08, New score: -8.15e+08
# Dropped column: Functional      Previous score: -8.15e+08, New score: -8.22e+08
# Dropped column: Electrical      Previous score: -8.22e+08, New score: -8.16e+08
# Dropped column: ScreenPorch     Previous score: -8.16e+08, New score: -8.32e+08
# Dropped column: LandSlope       Previous score: -8.32e+08, New score: -8.09e+08
# Dropped column: Exterior1st     Previous score: -8.09e+08, New score: -8.21e+08
# Dropped column: FireplaceQu     Previous score: -8.21e+08, New score: -8.18e+08
# Dropped column: LandContour     Previous score: -8.18e+08, New score: -8.20e+08
# Dropped column: SaleType        Previous score: -8.20e+08, New score: -8.15e+08
# Dropped column: PavedDrive      Previous score: -8.15e+08, New score: -8.19e+08
# Dropped column: MasVnrType      Previous score: -8.19e+08, New score: -8.28e+08
# Dropped column: LotShape        Previous score: -8.28e+08, New score: -8.13e+08
# Dropped column: SaleCondition   Previous score: -8.13e+08, New score: -8.14e+08
# Dropped column: Exterior2nd     Previous score: -8.14e+08, New score: -8.13e+08
# Dropped column: KitchenAbvGr    Previous score: -8.13e+08, New score: -8.17e+08
# Dropped column: BldgType        Previous score: -8.17e+08, New score: -8.10e+08
# Dropped column: HeatingQC       Previous score: -8.10e+08, New score: -8.16e+08
# Dropped column: RoofStyle       Previous score: -8.16e+08, New score: -8.17e+08
# Dropped column: BsmtExposure    Previous score: -8.17e+08, New score: -8.18e+08
# Dropped column: BsmtFullBath    Previous score: -8.18e+08, New score: -8.07e+08
# Dropped column: BsmtUnfSF       Previous score: -8.07e+08, New score: -8.19e+08
# Dropped column: HouseStyle      Previous score: -8.19e+08, New score: -8.15e+08
# Dropped column: MSZoning        Previous score: -8.15e+08, New score: -8.26e+08
# Dropped column: CentralAir      Previous score: -8.26e+08, New score: -8.15e+08
# Dropped column: WoodDeckSF      Previous score: -8.15e+08, New score: -8.20e+08
# Dropped column: Foundation      Previous score: -8.20e+08, New score: -8.03e+08
# Dropped column: OpenPorchSF     Previous score: -8.03e+08, New score: -8.08e+08
# Dropped column: BsmtFinType1    Previous score: -8.08e+08, New score: -8.12e+08
# Dropped column: HalfBath        Previous score: -8.12e+08, New score: -8.12e+08
# Dropped column: BedroomAbvGr    Previous score: -8.12e+08, New score: -8.17e+08
# Dropped column: GarageType      Previous score: -8.17e+08, New score: -8.37e+08
# Dropped column: OverallCond     Previous score: -8.37e+08, New score: -8.31e+08
# Dropped column: MSSubClass      Previous score: -8.31e+08, New score: -8.34e+08
# Dropped column: LotFrontage     Previous score: -8.34e+08, New score: -8.31e+08
# Dropped column: MasVnrArea      Previous score: -8.31e+08, New score: -8.25e+08
# Dropped column: Neighborhood    Previous score: -8.25e+08, New score: -8.61e+08
# Dropped column: YearRemodAdd    Previous score: -8.61e+08, New score: -8.63e+08
# Dropped column: Fireplaces      Previous score: -8.63e+08, New score: -8.73e+08
# Dropped column: TotRmsAbvGrd    Previous score: -8.73e+08, New score: -8.66e+08
# Dropped column: GarageFinish    Previous score: -8.66e+08, New score: -8.84e+08
# Dropped column: GarageYrBlt     Previous score: -8.84e+08, New score: -8.85e+08
# Dropped column: LotArea         Previous score: -8.85e+08, New score: -8.99e+08
# Dropped column: FullBath        Previous score: -8.99e+08, New score: -8.96e+08
# Dropped column: BsmtFinSF1      Previous score: -8.96e+08, New score: -9.68e+08
# Dropped column: KitchenQual     Previous score: -9.68e+08, New score: -9.73e+08
# Dropped column: 2ndFlrSF        Previous score: -9.73e+08, New score: -1.01e+09
# Dropped column: BsmtQual        Previous score: -1.01e+09, New score: -1.03e+09
# UFI results:
# Removed 77 features in  285.9 seconds.
# Initial score: -9.03e+08, best score: -8.03e+08, final score: -1.01e+09
# Remaining columns: ['ExterQual', 'OverallQual', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'GarageCars', 'GarageArea', 'BsmtQual']

# %%
res_permutation = feature_selection("permutation", common_params, X, y, verbose=True)
print(
    f"Permutation importance results:\n"
    f"Removed {len(X.columns) - len(res_permutation["final_columns"])} features in {res_permutation["run_time"]:6.1f} seconds. \n"
    f"Initial score: {res_permutation["init_score"]:.2e}, best score: {res_permutation["best_score"]:.2e}, final score: {res_permutation["final_score"]:.2e} \n"
    f"Remaining columns: {res_permutation["final_columns"]}"
)
# Out:
# Dropped column: MoSold          Previous score: -9.38e+08, New score: -9.36e+08
# Dropped column: BsmtUnfSF       Previous score: -9.36e+08, New score: -9.32e+08
# Dropped column: random_cat_100  Previous score: -9.32e+08, New score: -9.20e+08
# Dropped column: random_cat_50   Previous score: -9.20e+08, New score: -9.32e+08
# Dropped column: ExterCond       Previous score: -9.32e+08, New score: -9.09e+08
# Dropped column: random_num      Previous score: -9.09e+08, New score: -9.25e+08
# Dropped column: Exterior1st     Previous score: -9.25e+08, New score: -9.12e+08
# Dropped column: LandSlope       Previous score: -9.12e+08, New score: -9.30e+08
# Dropped column: FireplaceQu     Previous score: -9.30e+08, New score: -9.18e+08
# Dropped column: BsmtHalfBath    Previous score: -9.18e+08, New score: -9.08e+08
# Dropped column: YrSold          Previous score: -9.08e+08, New score: -9.13e+08
# Dropped column: BsmtFinType2    Previous score: -9.13e+08, New score: -9.18e+08
# Dropped column: random_cat_5    Previous score: -9.18e+08, New score: -8.98e+08
# Dropped column: random_cat_20   Previous score: -8.98e+08, New score: -8.84e+08
# Dropped column: random_cat_2    Previous score: -8.84e+08, New score: -8.81e+08
# Dropped column: LowQualFinSF    Previous score: -8.81e+08, New score: -9.02e+08
# Dropped column: EnclosedPorch   Previous score: -9.02e+08, New score: -8.95e+08
# Dropped column: PoolArea        Previous score: -8.95e+08, New score: -8.81e+08
# Dropped column: BsmtFinSF2      Previous score: -8.81e+08, New score: -8.88e+08
# Dropped column: BsmtCond        Previous score: -8.88e+08, New score: -8.79e+08
# Dropped column: RoofMatl        Previous score: -8.79e+08, New score: -8.89e+08
# Dropped column: random_cat_10   Previous score: -8.89e+08, New score: -8.79e+08
# Dropped column: Functional      Previous score: -8.79e+08, New score: -8.90e+08
# Dropped column: Fence           Previous score: -8.90e+08, New score: -8.93e+08
# Dropped column: 3SsnPorch       Previous score: -8.93e+08, New score: -8.77e+08
# Dropped column: GarageQual      Previous score: -8.77e+08, New score: -8.76e+08
# Dropped column: SaleCondition   Previous score: -8.76e+08, New score: -8.59e+08
# Dropped column: MiscVal         Previous score: -8.59e+08, New score: -8.82e+08
# Dropped column: Heating         Previous score: -8.82e+08, New score: -8.67e+08
# Dropped column: MiscFeature     Previous score: -8.67e+08, New score: -8.91e+08
# Dropped column: Exterior2nd     Previous score: -8.91e+08, New score: -8.63e+08
# Dropped column: Condition2      Previous score: -8.63e+08, New score: -8.71e+08
# Dropped column: GarageCond      Previous score: -8.71e+08, New score: -8.66e+08
# Dropped column: PoolQC          Previous score: -8.66e+08, New score: -8.84e+08
# Dropped column: Street          Previous score: -8.84e+08, New score: -8.53e+08
# Dropped column: Utilities       Previous score: -8.53e+08, New score: -8.60e+08
# Dropped column: Alley           Previous score: -8.60e+08, New score: -8.61e+08
# Dropped column: RoofStyle       Previous score: -8.61e+08, New score: -8.49e+08
# Dropped column: Condition1      Previous score: -8.49e+08, New score: -8.70e+08
# Dropped column: Electrical      Previous score: -8.70e+08, New score: -8.71e+08
# Dropped column: MasVnrType      Previous score: -8.71e+08, New score: -8.67e+08
# Dropped column: PavedDrive      Previous score: -8.67e+08, New score: -8.72e+08
# Dropped column: LandContour     Previous score: -8.72e+08, New score: -8.68e+08
# Dropped column: LotShape        Previous score: -8.68e+08, New score: -8.58e+08
# Dropped column: MSZoning        Previous score: -8.58e+08, New score: -8.84e+08
# Dropped column: BldgType        Previous score: -8.84e+08, New score: -8.71e+08
# Dropped column: WoodDeckSF      Previous score: -8.71e+08, New score: -8.73e+08
# Dropped column: LotConfig       Previous score: -8.73e+08, New score: -8.51e+08
# Dropped column: ScreenPorch     Previous score: -8.51e+08, New score: -8.65e+08
# Dropped column: KitchenAbvGr    Previous score: -8.65e+08, New score: -8.62e+08
# Dropped column: CentralAir      Previous score: -8.62e+08, New score: -8.95e+08
# Dropped column: BsmtFinType1    Previous score: -8.95e+08, New score: -8.66e+08
# Dropped column: GarageType      Previous score: -8.66e+08, New score: -8.77e+08
# Dropped column: Foundation      Previous score: -8.77e+08, New score: -8.74e+08
# Dropped column: HouseStyle      Previous score: -8.74e+08, New score: -8.86e+08
# Dropped column: HeatingQC       Previous score: -8.86e+08, New score: -8.58e+08
# Dropped column: MasVnrArea      Previous score: -8.58e+08, New score: -8.48e+08
# Dropped column: SaleType        Previous score: -8.48e+08, New score: -8.46e+08
# Dropped column: MSSubClass      Previous score: -8.46e+08, New score: -8.53e+08
# Dropped column: OpenPorchSF     Previous score: -8.53e+08, New score: -8.60e+08
# Dropped column: BsmtFullBath    Previous score: -8.60e+08, New score: -8.64e+08
# Dropped column: LotFrontage     Previous score: -8.64e+08, New score: -8.42e+08
# Dropped column: BsmtExposure    Previous score: -8.42e+08, New score: -8.49e+08
# Dropped column: OverallCond     Previous score: -8.49e+08, New score: -8.68e+08
# Dropped column: HalfBath        Previous score: -8.68e+08, New score: -8.73e+08
# Dropped column: BedroomAbvGr    Previous score: -8.73e+08, New score: -8.78e+08
# Dropped column: GarageYrBlt     Previous score: -8.78e+08, New score: -8.78e+08
# Dropped column: GarageFinish    Previous score: -8.78e+08, New score: -8.83e+08
# Dropped column: FullBath        Previous score: -8.83e+08, New score: -8.93e+08
# Dropped column: YearRemodAdd    Previous score: -8.93e+08, New score: -8.94e+08
# Dropped column: Fireplaces      Previous score: -8.94e+08, New score: -8.90e+08
# Dropped column: Neighborhood    Previous score: -8.90e+08, New score: -9.30e+08
# Dropped column: KitchenQual     Previous score: -9.30e+08, New score: -9.63e+08
# Dropped column: TotRmsAbvGrd    Previous score: -9.63e+08, New score: -9.58e+08
# Dropped column: BsmtQual        Previous score: -9.58e+08, New score: -9.69e+08
# Dropped column: GarageArea      Previous score: -9.69e+08, New score: -9.61e+08
# Dropped column: LotArea         Previous score: -9.61e+08, New score: -9.88e+08
# Dropped column: ExterQual       Previous score: -9.88e+08, New score: -1.01e+09
# Dropped column: BsmtFinSF1      Previous score: -1.01e+09, New score: -1.07e+09
# Dropped column: 2ndFlrSF        Previous score: -1.07e+09, New score: -1.10e+09
# Dropped column: 1stFlrSF        Previous score: -1.10e+09, New score: -1.06e+09
# Dropped column: YearBuilt       Previous score: -1.06e+09, New score: -1.22e+09
# Permutation importance results:
# Removed 81 features in  965.1 seconds.
# Initial score: -9.38e+08, best score: -8.42e+08, final score: -1.06e+09
# Remaining columns: ['OverallQual', 'TotalBsmtSF', 'GrLivArea', 'GarageCars', 'YearBuilt']
